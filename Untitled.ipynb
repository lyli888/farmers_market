# %%
# importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np

# %%
# making data frame from csv file 
df = pd.read_csv("fm_data/farmersmarket.csv")

# %%
df
# Out:
#            FMID                                        MarketName  \
# 0           NaN                                               NaN
# 1     1018261.0   Caledonia Farmers Market Association - Danville
# 2           NaN                                               NaN
# 3     1009994.0                       18th Street Farmer's Market
# 4           NaN                                               NaN
# ...         ...                                               ...
# 3083  1016909.0          Yreka Community Certified Farmers Market
# 3084        NaN                                               NaN
# 3085  1019863.0                         Zebulon Farm Fresh Market
# 3086        NaN                                               NaN
# 3087  1019792.0                Zelienople-Harmony Farmer's Market
#
#                                                 Website  \
# 0                                                   NaN
# 1                https://www.caledoniafarmersmarket.com
# ...

# %%
new_df = df.filter(['MarketName', 'x', 'y', 'WIC','Organic', 'Vegetables', 'Meat', 'Fruits', 'Grains']).copy()

# %%
new_df
# Out:
#                                             MarketName           x          y  \
# 0                                                  NaN         NaN        NaN
# 1      Caledonia Farmers Market Association - Danville  -72.140337  44.411036
# 2                                                  NaN         NaN        NaN
# 3                          18th Street Farmer's Market -103.662538  41.864268
# 4                                                  NaN         NaN        NaN
# ...                                                ...         ...        ...
# 3083          Yreka Community Certified Farmers Market -122.640134  41.707020
# 3084                                               NaN         NaN        NaN
# 3085                         Zebulon Farm Fresh Market  -78.314111  35.821835
# 3086                                               NaN         NaN        NaN
# 3087                Zelienople-Harmony Farmer's Market  -80.130181  40.792698
#
# ...

# %%
# using dropna() function    
new_df = new_df.dropna()

# %%
new_df
# Out:
#                                              MarketName           x  \
# 1       Caledonia Farmers Market Association - Danville  -72.140337
# 3                           18th Street Farmer's Market -103.662538
# 5     26th Annual Highlands Business Partnership's F...  -73.994358
# 7                              29 Palms Farmers' Market -116.058946
# 9             2nd Street Market - Five Rivers MetroPark  -84.181030
# ...                                                 ...         ...
# 3079  Your Neighborhood Farmers Market-Towne Lake at...  -95.687298
# 3081                 Ypsilanti Farmers Market- Downtown  -83.614751
# 3083           Yreka Community Certified Farmers Market -122.640134
# 3085                          Zebulon Farm Fresh Market  -78.314111
# 3087                 Zelienople-Harmony Farmer's Market  -80.130181
#
#               y WIC Organic Vegetables Meat Fruits Grains
# 1     44.411036   Y       Y          Y    Y      Y      N
# ...

# %%
# export cleaned csv to fm_output
new_df.to_csv("fm_output/farmers_market_cleaned.csv")
